# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=['EIN','NAME'],inplace=True)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T13','T12','T2','T25','T14','T29','T15','T17'] #'T9',

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() < 100].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
application_df.drop(columns=['STATUS','SPECIAL_CONSIDERATIONS'],inplace=True)

# %%
# Convert categorical data to numeric with `pd.get_dummies`
X = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = X['IS_SUCCESSFUL']
X.drop(columns='IS_SUCCESSFUL',inplace=True)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X.columns)
hl1 = 100
hl2 = 70
hl3 = 40
hl4 = 10
#hl5 = 50

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hl1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hl2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hl3, activation="relu"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hl4, activation="relu"))

# Fifth hidden layer
#nn.add(tf.keras.layers.Dense(units=hl5, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 100)               4800
#
#  dense_14 (Dense)            (None, 70)                7070
#
#  dense_15 (Dense)            (None, 40)                2840
#
#  dense_16 (Dense)            (None, 10)                410
#
#  dense_17 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 15131 (59.11 KB)
# Trainable params: 15131 (59.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5700 - accuracy: 0.7178
# Epoch 2/200
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5558 - accuracy: 0.7249
# Epoch 3/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5519 - accuracy: 0.7275
# Epoch 4/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5502 - accuracy: 0.7287
# Epoch 5/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5490 - accuracy: 0.7307
# Epoch 6/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5474 - accuracy: 0.7311
# Epoch 7/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.7317
# Epoch 8/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5463 - accuracy: 0.7318
# Epoch 9/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5459 - accuracy: 0.7320
# Epoch 10/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7319
# Epoch 11/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5442 - accuracy: 0.7332
# Epoch 12/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7330
# Epoch 13/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5434 - accuracy: 0.7327
# Epoch 14/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5428 - accuracy: 0.7343
# Epoch 15/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5427 - accuracy: 0.7345
# Epoch 16/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7343
# Epoch 17/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5418 - accuracy: 0.7346
# Epoch 18/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7354
# Epoch 19/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7353
# Epoch 20/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7352
# Epoch 21/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5403 - accuracy: 0.7343
# Epoch 22/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5397 - accuracy: 0.7352
# Epoch 23/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7352
# Epoch 24/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7347
# Epoch 25/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7365
# Epoch 26/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7354
# Epoch 27/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5386 - accuracy: 0.7370
# Epoch 28/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5386 - accuracy: 0.7368
# Epoch 29/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7371
# Epoch 30/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5382 - accuracy: 0.7366
# Epoch 31/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7365
# Epoch 32/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7364
# Epoch 33/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5371 - accuracy: 0.7368
# Epoch 34/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5374 - accuracy: 0.7373
# Epoch 35/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5369 - accuracy: 0.7371
# Epoch 36/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5372 - accuracy: 0.7377
# Epoch 37/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5365 - accuracy: 0.7370
# Epoch 38/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5364 - accuracy: 0.7369
# Epoch 39/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5364 - accuracy: 0.7364
# Epoch 40/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5366 - accuracy: 0.7374
# Epoch 41/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5364 - accuracy: 0.7378
# Epoch 42/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5361 - accuracy: 0.7369
# Epoch 43/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5362 - accuracy: 0.7374
# Epoch 44/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5357 - accuracy: 0.7374
# Epoch 45/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5359 - accuracy: 0.7380
# Epoch 46/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5359 - accuracy: 0.7369
# Epoch 47/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5354 - accuracy: 0.7378
# Epoch 48/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5358 - accuracy: 0.7374
# Epoch 49/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5353 - accuracy: 0.7385
# Epoch 50/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5354 - accuracy: 0.7382
# Epoch 51/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7376
# Epoch 52/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5341 - accuracy: 0.7382
# Epoch 53/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5349 - accuracy: 0.7379
# Epoch 54/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5349 - accuracy: 0.7375
# Epoch 55/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7378
# Epoch 56/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7374
# Epoch 57/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7382
# Epoch 58/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5342 - accuracy: 0.7383
# Epoch 59/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5337 - accuracy: 0.7390
# Epoch 60/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5338 - accuracy: 0.7390
# Epoch 61/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5349 - accuracy: 0.7383
# Epoch 62/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5336 - accuracy: 0.7383
# Epoch 63/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7392
# Epoch 64/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5335 - accuracy: 0.7378
# Epoch 65/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5332 - accuracy: 0.7386
# Epoch 66/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5340 - accuracy: 0.7390
# Epoch 67/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7388
# Epoch 68/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5329 - accuracy: 0.7378
# Epoch 69/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7381
# Epoch 70/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5326 - accuracy: 0.7384
# Epoch 71/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5327 - accuracy: 0.7385
# Epoch 72/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7388
# Epoch 73/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7394
# Epoch 74/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7391
# Epoch 75/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7388
# Epoch 76/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5326 - accuracy: 0.7387
# Epoch 77/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5324 - accuracy: 0.7393
# Epoch 78/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5334 - accuracy: 0.7389
# Epoch 79/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7398
# Epoch 80/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7391
# Epoch 81/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5318 - accuracy: 0.7383
# Epoch 82/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5319 - accuracy: 0.7388
# Epoch 83/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5319 - accuracy: 0.7390
# Epoch 84/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5319 - accuracy: 0.7395
# Epoch 85/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7390
# Epoch 86/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5318 - accuracy: 0.7397
# Epoch 87/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5315 - accuracy: 0.7390
# Epoch 88/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5326 - accuracy: 0.7390
# Epoch 89/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5325 - accuracy: 0.7398
# Epoch 90/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5316 - accuracy: 0.7389
# Epoch 91/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7400
# Epoch 92/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5320 - accuracy: 0.7390
# Epoch 93/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7385
# Epoch 94/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5325 - accuracy: 0.7389
# Epoch 95/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7398
# Epoch 96/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5309 - accuracy: 0.7393
# Epoch 97/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.7395
# Epoch 98/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7392
# Epoch 99/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7393
# Epoch 100/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7392
# Epoch 101/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7391
# Epoch 102/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5311 - accuracy: 0.7396
# Epoch 103/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5314 - accuracy: 0.7394
# Epoch 104/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5312 - accuracy: 0.7394
# Epoch 105/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7385
# Epoch 106/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7394
# Epoch 107/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5308 - accuracy: 0.7392
# Epoch 108/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7392
# Epoch 109/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5311 - accuracy: 0.7388
# Epoch 110/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5305 - accuracy: 0.7395
# Epoch 111/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7386
# Epoch 112/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5415 - accuracy: 0.7394
# Epoch 113/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5332 - accuracy: 0.7392
# Epoch 114/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7388
# Epoch 115/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5304 - accuracy: 0.7399
# Epoch 116/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5308 - accuracy: 0.7398
# Epoch 117/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7395
# Epoch 118/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5305 - accuracy: 0.7394
# Epoch 119/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5306 - accuracy: 0.7393
# Epoch 120/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5303 - accuracy: 0.7390
# Epoch 121/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5306 - accuracy: 0.7401
# Epoch 122/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5307 - accuracy: 0.7391
# Epoch 123/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5309 - accuracy: 0.7398
# Epoch 124/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5301 - accuracy: 0.7402
# Epoch 125/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7396
# Epoch 126/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5310 - accuracy: 0.7394
# Epoch 127/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5308 - accuracy: 0.7399
# Epoch 128/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5304 - accuracy: 0.7397
# Epoch 129/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5305 - accuracy: 0.7402
# Epoch 130/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7396
# Epoch 131/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5300 - accuracy: 0.7396
# Epoch 132/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7393
# Epoch 133/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5314 - accuracy: 0.7399
# Epoch 134/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5301 - accuracy: 0.7397
# Epoch 135/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5301 - accuracy: 0.7396
# Epoch 136/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5319 - accuracy: 0.7393
# Epoch 137/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7391
# Epoch 138/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5305 - accuracy: 0.7390
# Epoch 139/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5298 - accuracy: 0.7398
# Epoch 140/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5302 - accuracy: 0.7401
# Epoch 141/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5305 - accuracy: 0.7395
# Epoch 142/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5298 - accuracy: 0.7392
# Epoch 143/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7399
# Epoch 144/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5304 - accuracy: 0.7400
# Epoch 145/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5298 - accuracy: 0.7406
# Epoch 146/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7398
# Epoch 147/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5299 - accuracy: 0.7391
# Epoch 148/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5305 - accuracy: 0.7388
# Epoch 149/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5300 - accuracy: 0.7398
# Epoch 150/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5297 - accuracy: 0.7393
# Epoch 151/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5298 - accuracy: 0.7399
# Epoch 152/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5315 - accuracy: 0.7395
# Epoch 153/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5312 - accuracy: 0.7393
# Epoch 154/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5301 - accuracy: 0.7400
# Epoch 155/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5298 - accuracy: 0.7395
# Epoch 156/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7398
# Epoch 157/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5296 - accuracy: 0.7400
# Epoch 158/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5297 - accuracy: 0.7396
# Epoch 159/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5315 - accuracy: 0.7392
# Epoch 160/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5295 - accuracy: 0.7404
# Epoch 161/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5296 - accuracy: 0.7393
# Epoch 162/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5301 - accuracy: 0.7395
# Epoch 163/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5300 - accuracy: 0.7395
# Epoch 164/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5296 - accuracy: 0.7399
# Epoch 165/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5301 - accuracy: 0.7404
# Epoch 166/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5296 - accuracy: 0.7394
# Epoch 167/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5311 - accuracy: 0.7395
# Epoch 168/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5299 - accuracy: 0.7395
# Epoch 169/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5297 - accuracy: 0.7397
# Epoch 170/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5303 - accuracy: 0.7405
# Epoch 171/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5294 - accuracy: 0.7396
# Epoch 172/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5295 - accuracy: 0.7395
# Epoch 173/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5298 - accuracy: 0.7397
# Epoch 174/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5301 - accuracy: 0.7394
# Epoch 175/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5297 - accuracy: 0.7402
# Epoch 176/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5303 - accuracy: 0.7398
# Epoch 177/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5303 - accuracy: 0.7402
# Epoch 178/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5300 - accuracy: 0.7390
# Epoch 179/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5296 - accuracy: 0.7397
# Epoch 180/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5293 - accuracy: 0.7395
# Epoch 181/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5294 - accuracy: 0.7400
# Epoch 182/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5292 - accuracy: 0.7403
# Epoch 183/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5298 - accuracy: 0.7404
# Epoch 184/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5292 - accuracy: 0.7397
# Epoch 185/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5310 - accuracy: 0.7394
# Epoch 186/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5294 - accuracy: 0.7399
# Epoch 187/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5291 - accuracy: 0.7388
# Epoch 188/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5298 - accuracy: 0.7400
# Epoch 189/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5296 - accuracy: 0.7404
# Epoch 190/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5550 - accuracy: 0.7394
# Epoch 191/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5305 - accuracy: 0.7397
# Epoch 192/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5286 - accuracy: 0.7406
# Epoch 193/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5289 - accuracy: 0.7400
# Epoch 194/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5289 - accuracy: 0.7399
# Epoch 195/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5289 - accuracy: 0.7404
# Epoch 196/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5291 - accuracy: 0.7395
# Epoch 197/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5293 - accuracy: 0.7398
# Epoch 198/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5290 - accuracy: 0.7405
# Epoch 199/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5291 - accuracy: 0.7394
# Epoch 200/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5298 - accuracy: 0.7394

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 2s - loss: 0.5754 - accuracy: 0.7378 - 2s/epoch - 8ms/step
# Loss: 0.5753679275512695, Accuracy: 0.7378425598144531

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
